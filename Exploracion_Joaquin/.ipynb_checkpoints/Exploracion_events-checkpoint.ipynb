# %%
import pandas as pd
import numpy as np
import datetime
import calendar
import matplotlib.pyplot as plt
import seaborn as sns

from func import *

# %%
ev_types = {'event_id':'int64',
            'ref_type':'category',
            'ref_hash':'int64',
            'application_id':'int64',
            'attributed':'bool',
            'device_countrycode':'category',
            'device_os_version':'float64',
            'device_brand':'float64',
            'device_model':'float64',
            'device_city':'float64',
            'session_user_agent':'float64',
            'trans_id':'category',
            'user_agent':'float64',
            'event_uuid':'object',
            'carrier':'float64',
            'kind':'float64',
            'device_os':'category',
            'wifi':'category',
            'connection_type':'category',
            'ip_address':'int64',
            'device_language':'float64'}

events = pd.read_csv('../../../datos_tp/events.csv', dtype = ev_types)

# %%
installs = pd.read_csv('../../../datos_tp/installs.csv')
installs.rename(columns={'created':'date'},inplace=True)
installs['date'] = pd.to_datetime(installs['date'], format = '%Y-%m-%d %H:%M:%S')
events['date'] = pd.to_datetime(events['date'], format = '%Y-%m-%d %H:%M:%S')
installs['ins'] = 1
events['ins'] = 0

# %%
concat_types = {
            'ref_type':'category',
            'ref_hash':'int64',
            'application_id':'int64',
            'attributed':'category',
            'device_countrycode':'category',
            #'device_os_version':'float64',
            #'device_brand':'float64',
            #'device_model':'float64',
            #'device_city':'float64',
            #'session_user_agent':'float64',
            'trans_id':'category',
            #'user_agent':'float64',
            'event_uuid':'object',
            #'carrier':'float64',
            #'click_hash':'float64',
            #'kind':'float64',
            'device_os':'category',
            'wifi':'category',
            'connection_type':'category',
            'ip_address':'int64',
            #'device_language':'float64',
            'implicit':'category'}

tot_events = pd.concat([installs,events])
tot_events = tot_events.astype(concat_types)
#tot_events.info()
# Out:
# C:\Users\Joaquin\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
tot_events.loc[(tot_events['ins'] == 1), 'event_id'] = 'install'
tot_events.sort_values(by=["ip_address", "date"], inplace = True)

# %%
#tot_events.head()

# %%
#PARA TRABAJAR SOLO CON LOS EVENTOS QUE SUCEDIERON MAS DE n VECES, DESCOMENTO ESTA CELDA
n=500
ev_count = tot_events.event_id.value_counts()
ev_count = ev_count.reset_index().rename(columns={'index':'event'})
ev_count = ev_count[ev_count['event_id'] > n]
tot_events = tot_events.loc[tot_events.event_id.isin(ev_count.event)]

# %%
#top10apps = tot_events.application_id.value_counts().head(10)
#top10apps = top10apps.reset_index().rename(columns={'index':'app','application_id':'repeats'})

# %%
#COMO VEO QUE EL FLUJO DE EVENTOS DEPENDE MUCHO DE EL APPLICATION ID
#EN ESTA CELDA FILTRO EL DATAFRAME POR APLICACION
#PARA TRABAJAR SOBRE UNA APLICACION EN PARTICULAR, DESCOMENTO ESTA CELDA

#tot_events = tot_events.loc[tot_events.application_id == 145]
#tot_events.event_id.value_counts()

# %%
tot_events.reset_index(inplace=True)
sess = generateSessions(tot_events)
tot_events['session'] = sess
tot_events[['ip_address','date','session']].head()
#521945665648320	ver este IP
# Out:
# C:\Users\Joaquin\Desktop\Facu\Datos\TP_1\Repo\7506-organizacion-de-datos-TP1-1C2019\Exploracion_Joaquin\func.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   nextEvents.loc[nextEvents.index[-1]+1] = ev
#        ip_address                    date  session
# 0   5287755497790 2019-03-07 14:38:21.082      0.0
# 1   5287755497790 2019-03-07 14:39:00.166      0.0
# 2  87345868419849 2019-03-10 15:13:05.468      0.0
# 3  87345868419849 2019-03-10 15:13:06.619      0.0
# 4  87345868419849 2019-03-10 15:13:13.086      0.0

# %%
tot_events.groupby(['ip_address','session','application_id','event_id']).agg({'ins':'sum'}).reset_index().head()

# %%
#ev_on_app = tot_events.groupby(['application_id','event_id']).agg({'event_id':'count'}).rename(columns={'event_id':'event_counts'}).unstack()
#ev_on_app.reset_index(inplace=True)

# %%
next_event = pd.DataFrame()
next_event['event'] = tot_events.event_id
next_event['session'] = tot_events.session
next_event['ip_address'] = tot_events.ip_address
next_event.index = next_event.index+1
next_event['next_sess'] = tot_events.session
next_event['next_ip'] = tot_events.ip_address
next_event.loc[(next_event.session != next_event.next_sess) | (next_event.ip_address != next_event.next_ip), 'next_event'] = -1
next_event.loc[(next_event.session == next_event.next_sess) & (next_event.ip_address == next_event.next_ip), 'next_event'] = tot_events.event_id

#LAS SIGUIENTES LINEAS SON SOLO PARA ARMAR MATRIZ DE EVENTOS, PARA EXPLORAR OTROS DATOS LAS COMENTO
#next_event = next_event[['event','next_event']]
#next_event.head(10)

# %%
nev_group = next_event.groupby(['event','next_event']).agg({'next_event':'count'})
#SI QUIERO EL INVERSO (LA CANTIDAD DE EVENTOS DEPENDIENDO DEL NEXT_EVENT) CAMBIO ACA ARRIBA ESOS CAMPOS, NO SOBRE NEV_GROUP
nev_group.head()
# Out:
#                   next_event
# event next_event
# 1.0   -1.0             42589
#        1.0              6043
#        22.0             5239
#        23.0                1
#        27.0                1

# %%
#PARA VERLA MEJOR TENGO QUE FILTRAR LOS EVENTOS UNICOS
nev_group = nev_group.unstack('event')
nev_group

#SI DESCOMENTO VEO LA MATRIZ
# Out:
#            next_event                                                      \
# event             1.0    20.0     21.0      22.0     23.0    24.0    25.0
# next_event
# -1.0          42589.0    90.0    573.0  168473.0    742.0    38.0    62.0
# 1.0            6043.0     1.0      4.0    5393.0      5.0     NaN     NaN
# 20.0              NaN  6237.0    213.0     142.0   1118.0    65.0    58.0
# 21.0              NaN   365.0  17578.0    2068.0   4788.0   671.0   623.0
# 22.0           5239.0   176.0   1155.0  358360.0   2073.0   117.0   210.0
# 23.0              1.0   843.0   6184.0    2661.0  22884.0  1392.0  1257.0
# 24.0              NaN    49.0    245.0      97.0   1913.0  1007.0    13.0
# 25.0              NaN    68.0    165.0     128.0   1849.0    26.0   895.0
# 27.0              1.0    15.0     98.0     969.0    186.0    28.0    14.0
# 30.0              NaN     NaN      NaN     186.0      4.0     NaN     3.0
# 31.0            784.0     2.0      9.0    3587.0     10.0     NaN     NaN
# 33.0           2800.0     NaN      NaN      41.0      NaN     NaN     NaN
# 37.0              8.0     NaN      NaN     132.0      NaN     NaN     NaN
# 40.0           3225.0     NaN      NaN     157.0      1.0     NaN     NaN
# 41.0           1536.0     NaN      NaN      43.0      NaN     NaN     NaN
# 50.0             80.0     NaN      NaN    2106.0      1.0     NaN     NaN
# 51.0              3.0     NaN      NaN   10442.0      NaN     NaN     NaN
# 52.0              NaN     NaN      NaN     260.0      NaN     NaN     NaN
# 53.0              NaN     NaN      NaN     779.0      NaN     NaN     NaN
# 55.0              NaN     NaN      NaN      16.0      NaN     NaN     NaN
# 58.0              1.0     NaN      NaN    2214.0      NaN     NaN     NaN
# 59.0              NaN     NaN      NaN    1041.0      NaN     NaN     NaN
# 60.0              3.0     NaN      NaN    1598.0      NaN     NaN     NaN
# 62.0              NaN     NaN      NaN      75.0      NaN     NaN     NaN
# 63.0              NaN     NaN      NaN      98.0      NaN     NaN     NaN
# 64.0              NaN     NaN      NaN      48.0      NaN     NaN     NaN
# 80.0           1868.0     NaN      NaN     114.0      NaN     NaN     NaN
# 81.0          10508.0     NaN      NaN      66.0      NaN     NaN     NaN
# 82.0              NaN     NaN      NaN       NaN      NaN     NaN     NaN
# 83.0              NaN     NaN      NaN       NaN      NaN     NaN     NaN
# ...               ...     ...      ...       ...      ...     ...     ...
# 273.0           980.0     1.0      NaN   10530.0      5.0     1.0     NaN
# 274.0           212.0     NaN      NaN    3105.0      3.0     1.0     NaN
# 275.0           111.0     NaN      NaN     297.0      NaN     NaN     NaN
# 302.0             NaN     NaN      NaN    1082.0      NaN     NaN     NaN
# 304.0             2.0     NaN      NaN     329.0      NaN     NaN     NaN
# 305.0             NaN     NaN      NaN       NaN      NaN     NaN     NaN
# 310.0          6401.0     NaN      NaN      42.0      NaN     NaN     NaN
# 311.0           293.0     NaN      NaN       NaN      NaN     NaN     NaN
# 327.0             NaN     NaN      NaN       8.0      NaN     NaN     NaN
# 328.0             NaN     NaN      NaN       4.0      NaN     NaN     NaN
# 329.0            11.0     NaN      NaN      35.0      1.0     NaN     NaN
# 335.0             9.0     NaN      NaN     360.0      NaN     NaN     NaN
# 346.0            21.0     NaN      NaN     406.0      NaN     NaN     NaN
# 347.0             NaN     NaN      NaN      32.0      NaN     NaN     NaN
# 348.0             NaN     NaN      NaN      36.0      NaN     NaN     NaN
# 349.0             1.0     NaN      NaN      15.0      NaN     NaN     NaN
# 350.0             NaN     NaN      NaN      10.0      NaN     NaN     NaN
# 352.0             NaN     NaN      NaN       1.0      NaN     NaN     NaN
# 354.0             2.0     NaN      NaN      24.0      NaN     NaN     NaN
# 376.0             NaN     NaN      NaN       NaN      NaN     NaN     NaN
# 378.0             NaN     NaN      NaN       NaN      NaN     NaN     NaN
# 440.0             NaN     NaN      NaN       NaN      NaN     NaN     NaN
# 441.0            18.0     NaN      NaN     104.0      1.0     NaN     NaN
# 450.0             NaN     NaN      NaN      20.0      NaN     NaN     NaN
# 452.0             NaN     NaN      NaN       NaN      NaN     NaN     NaN
# 513.0            24.0     NaN      NaN    5967.0      NaN     NaN     NaN
# 653.0             1.0     NaN      NaN     240.0      NaN     NaN     NaN
# 695.0             1.0     NaN      NaN      27.0      NaN     NaN     NaN
# 698.0             NaN     NaN      NaN       1.0      NaN     NaN     NaN
# install          33.0     NaN      NaN     560.0      NaN     NaN     NaN
#
#                                       ...                                   \
# event         27.0   30.0      31.0   ...     378.0  440.0   441.0   450.0
# next_event                            ...
# -1.0         112.0   45.0  143178.0   ...      79.0   77.0  6140.0   350.0
# 1.0            4.0    2.0     884.0   ...       NaN    NaN    28.0     3.0
# 20.0           9.0    NaN       NaN   ...       NaN    NaN     NaN     NaN
# 21.0          76.0    NaN       3.0   ...       NaN    NaN     NaN     NaN
# 22.0         566.0  216.0    3303.0   ...       NaN    NaN   112.0    17.0
# 23.0         292.0    2.0       3.0   ...       NaN    NaN     NaN     NaN
# 24.0          12.0    NaN       NaN   ...       NaN    NaN     NaN     NaN
# 25.0           3.0    NaN       NaN   ...       NaN    NaN     NaN     NaN
# 27.0        2233.0    2.0       3.0   ...       NaN    NaN     NaN     NaN
# 30.0           1.0   99.0       NaN   ...       NaN    NaN     NaN     NaN
# 31.0           9.0    1.0  192206.0   ...       NaN    NaN    76.0     3.0
# 33.0           NaN    NaN       8.0   ...       NaN    NaN     NaN     NaN
# 37.0           1.0    NaN       4.0   ...       NaN    NaN     NaN     NaN
# 40.0           NaN    NaN      21.0   ...       NaN    NaN     2.0     NaN
# 41.0           NaN    NaN       8.0   ...       NaN    NaN     NaN     NaN
# 50.0          14.0    1.0      84.0   ...       NaN    NaN     2.0     1.0
# 51.0           NaN    2.0       6.0   ...       NaN    NaN     NaN     NaN
# 52.0           NaN    NaN       NaN   ...       NaN    NaN     NaN     NaN
# 53.0           NaN   18.0       5.0   ...       NaN    NaN     NaN     NaN
# 55.0           NaN    8.0       NaN   ...       NaN    NaN     NaN     NaN
# 58.0           NaN   15.0       7.0   ...       NaN    NaN     NaN     NaN
# 59.0           NaN    8.0       NaN   ...       NaN    NaN     NaN     NaN
# 60.0           NaN    8.0       5.0   ...       NaN    NaN     NaN     NaN
# 62.0           NaN    NaN       NaN   ...       NaN    NaN     NaN     NaN
# 63.0           NaN    NaN       NaN   ...       NaN    NaN     NaN     NaN
# 64.0           NaN    NaN       1.0   ...       NaN    NaN     NaN     NaN
# 80.0           NaN    NaN      27.0   ...       NaN    NaN     2.0     NaN
# 81.0           NaN    NaN      18.0   ...       NaN    NaN     3.0     NaN
# 82.0           NaN    NaN       NaN   ...       NaN    NaN     NaN     NaN
# 83.0           NaN    NaN       NaN   ...       NaN    NaN     NaN     NaN
# ...            ...    ...       ...   ...       ...    ...     ...     ...
# 273.0         27.0   10.0     281.0   ...       NaN    NaN     4.0     NaN
# 274.0          5.0    NaN      66.0   ...       NaN    NaN     NaN     NaN
# 275.0          NaN    NaN       1.0   ...       NaN    NaN     NaN     NaN
# 302.0        308.0    2.0       2.0   ...       NaN    NaN     NaN     NaN
# 304.0          NaN    1.0       8.0   ...       NaN    NaN     NaN     NaN
# 305.0          NaN    NaN       NaN   ...       NaN    NaN     NaN     NaN
# 310.0          NaN    NaN      19.0   ...       NaN    NaN     2.0     NaN
# 311.0          NaN    NaN       1.0   ...       NaN    NaN     NaN     NaN
# 327.0          NaN    NaN     544.0   ...       NaN    NaN     NaN     NaN
# 328.0          NaN    NaN    1656.0   ...       NaN    NaN     NaN     NaN
# 329.0          NaN    NaN   52955.0   ...       NaN    NaN     NaN     NaN
# 335.0          3.0    NaN      13.0   ...       NaN    NaN     NaN     NaN
# 346.0          NaN    NaN      26.0   ...       NaN    NaN     3.0     1.0
# 347.0          NaN    NaN       1.0   ...       NaN    NaN     NaN     NaN
# 348.0          NaN    NaN       5.0   ...       NaN    NaN     NaN     NaN
# 349.0          NaN    NaN       1.0   ...       NaN    NaN     NaN     NaN
# 350.0          NaN    NaN       1.0   ...       NaN    NaN     NaN     NaN
# 352.0          NaN    NaN       NaN   ...       NaN    NaN     NaN     NaN
# 354.0          NaN    NaN       2.0   ...       NaN    NaN     NaN     NaN
# 376.0          NaN    NaN       NaN   ...     416.0    NaN     NaN     NaN
# 378.0          NaN    NaN       NaN   ...    1249.0    NaN     NaN     NaN
# 440.0          NaN    NaN       NaN   ...       NaN  786.0     NaN     NaN
# 441.0          NaN    NaN      46.0   ...       NaN    NaN   535.0     1.0
# 450.0          NaN    NaN       3.0   ...       NaN    NaN     NaN  1615.0
# 452.0          NaN    NaN       NaN   ...       NaN    NaN     NaN     NaN
# 513.0          2.0    1.0      59.0   ...       NaN    NaN     NaN     6.0
# 653.0         15.0    NaN       NaN   ...       NaN    NaN     NaN     NaN
# 695.0          NaN    NaN     517.0   ...       NaN    NaN     NaN     NaN
# 698.0          NaN    NaN       NaN   ...       NaN    NaN     NaN     NaN
# install        NaN    NaN      79.0   ...       2.0    NaN     2.0     NaN
#
#
# event        452.0   513.0  653.0  695.0   698.0 install
# next_event
# -1.0        2182.0  1824.0    8.0   37.0    43.0   464.0
# 1.0            NaN    65.0    2.0    5.0     NaN   270.0
# 20.0           NaN     NaN    NaN    NaN     NaN     NaN
# 21.0           NaN     NaN    NaN    NaN     NaN     NaN
# 22.0           NaN  4880.0  235.0   80.0     1.0  1469.0
# 23.0           NaN     NaN    NaN    NaN     NaN     NaN
# 24.0           NaN     NaN    NaN    NaN     NaN     NaN
# 25.0           NaN     NaN    NaN    NaN     NaN     NaN
# 27.0           NaN     4.0    9.0    1.0     NaN     NaN
# 30.0           NaN     NaN    1.0    NaN     NaN     NaN
# 31.0           NaN   100.0    1.0  416.0     1.0   191.0
# 33.0           NaN     NaN    NaN    NaN     NaN     NaN
# 37.0           NaN     8.0    NaN    NaN     NaN     NaN
# 40.0           NaN     4.0    NaN    NaN     NaN     2.0
# 41.0           NaN     2.0    NaN    NaN     NaN     NaN
# 50.0          38.0   105.0    1.0    4.0     NaN     3.0
# 51.0           NaN     NaN    NaN    NaN     NaN     NaN
# 52.0           NaN     NaN    NaN    NaN     NaN     NaN
# 53.0           NaN     NaN    NaN    NaN     NaN     NaN
# 55.0           NaN     NaN    NaN    NaN     NaN     NaN
# 58.0           NaN     NaN    NaN    NaN     NaN     NaN
# 59.0           NaN     NaN    NaN    NaN     NaN     NaN
# 60.0           NaN     NaN    NaN    NaN     NaN     NaN
# 62.0           NaN     NaN    NaN    NaN     NaN     NaN
# 63.0           NaN     NaN    NaN    NaN     NaN     NaN
# 64.0           NaN     NaN    NaN    NaN     NaN     NaN
# 80.0           NaN     5.0    NaN    NaN     NaN   404.0
# 81.0           NaN     1.0    NaN    NaN     NaN   453.0
# 82.0           NaN     NaN    NaN    NaN     NaN     6.0
# 83.0           NaN     NaN    NaN    NaN     NaN     NaN
# ...            ...     ...    ...    ...     ...     ...
# 273.0          NaN   300.0   12.0   25.0     NaN     2.0
# 274.0          NaN    66.0    3.0    6.0     NaN     1.0
# 275.0          NaN     NaN    NaN    NaN     NaN     NaN
# 302.0          NaN    10.0    1.0    NaN     NaN     NaN
# 304.0          NaN     NaN    NaN    NaN     NaN     NaN
# 305.0          NaN     NaN    NaN    NaN     NaN     NaN
# 310.0          NaN     NaN    NaN    NaN     NaN     NaN
# 311.0          NaN     NaN    NaN    NaN     NaN     NaN
# 327.0          NaN     NaN    NaN    NaN     NaN     NaN
# 328.0          NaN     NaN    NaN    NaN     NaN     NaN
# 329.0          NaN     1.0    NaN    NaN     NaN     NaN
# 335.0          NaN    26.0    NaN    1.0     NaN     2.0
# 346.0          NaN     NaN    NaN    NaN     NaN     NaN
# 347.0          NaN     NaN    NaN    NaN     NaN     NaN
# 348.0          NaN     NaN    NaN    NaN     NaN     NaN
# 349.0          NaN     NaN    NaN    NaN     NaN     NaN
# 350.0          NaN     NaN    NaN    NaN     NaN     NaN
# 352.0          NaN     NaN    NaN    NaN     NaN     NaN
# 354.0          NaN     NaN    NaN    NaN     NaN     NaN
# 376.0          NaN     NaN    NaN    NaN     NaN     2.0
# 378.0          NaN     NaN    NaN    NaN     NaN     3.0
# 440.0          NaN     NaN    NaN    NaN     NaN     NaN
# 441.0          NaN     NaN    NaN    NaN     1.0     1.0
# 450.0          NaN     4.0    NaN    NaN     NaN     NaN
# 452.0        295.0     NaN    NaN    NaN     NaN     NaN
# 513.0          NaN  4972.0    NaN    3.0     NaN    37.0
# 653.0          NaN     NaN   98.0    NaN     NaN     NaN
# 695.0          NaN     2.0    NaN   81.0     NaN     NaN
# 698.0          NaN     NaN    NaN    NaN  1268.0     NaN
# install        NaN    32.0    1.0    NaN     NaN    47.0
#
# [116 rows x 115 columns]

# %%
#CELDA PARA HEATMAP DE FLUJO DE EVENTOS PARA ALGUN APPLICATION_ID

nev_group.columns = nev_group.columns.get_level_values(1)
nev_group.fillna(0, inplace=True)
ax = plt.axes()
ax.set_title('Next events for app 145')
sns.heatmap(nev_group,ax = ax)

# %%
#PISO LA MATRIZ O EL AGRUPAMIENTO
nev_group = nev_group.rename(columns = {'next_event':'repeats'}).reset_index()
nev_group.head()
# Out:
# event  next_event      1.0  36.0    161.0    162.0  164.0  165.0  166.0  167.0
# 0            -1.0   3454.0   0.0  28142.0  14656.0  520.0  700.0  282.0  150.0
# 1             1.0    201.0   0.0  26272.0    743.0  194.0   96.0   45.0   31.0
# 2           161.0  41578.0   1.0  79658.0  17893.0  997.0    0.0  370.0  243.0
# 3           162.0    220.0   0.0  30847.0   6535.0  584.0    0.0  187.0   30.0
# 4           164.0      7.0   0.0   2104.0     11.0  231.0    0.0    2.0    0.0

# %%
wifi_counts = installs.wifi.value_counts()
wifi_counts.plot.pie()

# %%
#events['counts'] = 1
#app_city_group = events.groupby(['application_id','device_city']).agg({'counts':'sum'}).reset_index()
#app_city_group.head()
#app_city_group.groupby(['application_id','device_city']).agg({'counts':'max'})

# %%
#tot_events['repeats'] = 1
#top10apps_ev = tot_events.loc[tot_events.application_id.isin(top10apps.app)]

#ev_count = top10apps_ev.event_id.value_counts()
#ev_count = ev_count[ev_count > 2]
#ev_count = ev_count.reset_index().rename(columns={'index':'event','event_id':'repeats'})
#top10apps_ev = top10apps_ev.loc[(top10apps_ev.ins == 1)]

#top10apps_ev.groupby(['application_id']).agg({'repeats':'sum'})
# Out:
# Empty DataFrame
# Columns: [repeats]
# Index: []

# %%
installs.ref_hash.value_counts()
# Out:
# 5208834946313176321    4
# 3272750442824629569    4
# 1999001885916451618    3
# 2457547163021424058    3
# 2515049144505739996    3
# 5376622639905210608    3
# 470581161921490835     3
# 2807966731127456435    3
# 394181128078904930     3
# 1332624341050561368    3
# 8209340170282049305    3
# 1826618012885478111    3
# 6207088909238189318    3
# 4603142710878547974    3
# 4587898421740190562    3
# 3429460795301152906    3
# 1838099903940931904    3
# 808602801225309575     3
# 2756309363004630634    3
# 5716316704073038128    3
# 1951826604052927528    3
# 5707101515634134793    3
# 3293250764324184935    3
# 6697381140026413622    2
# 1051816244049516468    2
# 2429923283539157643    2
# 8378288095655268347    2
# 4049391409413329307    2
# 1162390149017457197    2
# 8956666120381022264    2
#                       ..
# 432026705480919604     1
# 868940215859934734     1
# 4424921869962083331    1
# 667593224187123722     1
# 826262859425189535     1
# 3807326297196549242    1
# 453115979634562298     1
# 2987878111541902309    1
# 3081130218041894318    1
# 1877503968466110352    1
# 530219043126256082     1
# 3403340613216452169    1
# 715041527646407093     1
# 6429559139633791703    1
# 2864803356152732457    1
# 4685290250772517185    1
# 2689158357454731145    1
# 4881524263181588033    1
# 4174271766196277740    1
# 25409974890453604      1
# 8155732787939289418    1
# 3129511836481108800    1
# 3692618985154753222    1
# 2044498063868721248    1
# 4577579502532667479    1
# 965380799674979884     1
# 4869208196560718312    1
# 5933966659490510327    1
# 3730165007009583572    1
# 3229160466581534722    1
# Name: ref_hash, Length: 3008, dtype: int64
